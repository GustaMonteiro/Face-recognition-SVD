# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as img

# %%
M = np.reshape(np.asarray(img.open("treino (1).pgm"),dtype=np.float32)/255,(32256,1))
for i in range(2,2377):
    name = "treino (" + str(i) + ").pgm"
    M = np.hstack((M,np.reshape(np.asarray(img.open(name),dtype=np.float32)/255,(32256,1))))
print(M.shape)
# Out:
# (32256, 999)

# %%
M = M - np.mean(M)
print(M.shape)
# Out:
# (32256, 999)

# %%
u, s, vt = np.linalg.svd(M,full_matrices=False)
print(u.shape)
# Out:
# (32256, 999)

# %%
r = 50
imagemTeste = np.reshape(np.asarray(img.open("teste (25).pgm"),dtype=np.float32)/255,(32256,1))
imagemTesteProjetada = u[:,0:r].T@imagemTeste
imagemTesteProjetada = u[:,0:r]@imagemTesteProjetada
distancia = 500
index=-1
for i in range(1,2377):
    name = "treino (" + str(i) + ").pgm"
    imagemAnalisada = np.reshape(np.asarray(img.open(name),dtype=np.float32)/255,(32256,1))
    imagemAnalisadaProjetada = u[:,0:r].T@imagemAnalisada
    imagemAnalisadaProjetada = u[:,0:r]@imagemAnalisadaProjetada
    dist = np.linalg.norm(imagemTesteProjetada-imagemAnalisadaProjetada)
    if dist < distancia:
        distancia = dist
        index = i
plt.imshow(np.reshape(imagemTeste,(192,168)),cmap='gray')
plt.title("Imagem teste")
plt.axis("off")
plt.show()
name = "treino (" + str(index) + ").pgm"
plt.title("Imagem encontrada")
plt.imshow(np.asarray(img.open(name),dtype=np.float32)/255,cmap='gray')
plt.axis("off")
plt.show()

# %%
x = np.array([0])
y = np.array([0])
for i in range(0,2376,20):
    y = np.hstack((y,100*(np.sum(s[0:i])/np.sum(s))))
    x = np.hstack((x,i))
    #print("para " + str(i) + " autovetores, variabilidade acumulada de: " + str(100*(np.sum(s[0:i])/np.sum(s))))
print(x)
print(y)
# Out:
# para 0 autovetores, variabilidade acumulada de: 0.0
# para 20 autovetores, variabilidade acumulada de: 35.09192168712616
# para 40 autovetores, variabilidade acumulada de: 44.94474232196808
# para 60 autovetores, variabilidade acumulada de: 51.60194635391235
# para 80 autovetores, variabilidade acumulada de: 56.69694542884827
# para 100 autovetores, variabilidade acumulada de: 60.686689615249634
# para 120 autovetores, variabilidade acumulada de: 63.994646072387695
# para 140 autovetores, variabilidade acumulada de: 66.79735779762268
# para 160 autovetores, variabilidade acumulada de: 69.21147108078003
# para 180 autovetores, variabilidade acumulada de: 71.3482141494751
# para 200 autovetores, variabilidade acumulada de: 73.2589602470398
# para 220 autovetores, variabilidade acumulada de: 74.98707175254822
# para 240 autovetores, variabilidade acumulada de: 76.56339406967163
# para 260 autovetores, variabilidade acumulada de: 78.01278233528137
# para 280 autovetores, variabilidade acumulada de: 79.35775518417358
# para 300 autovetores, variabilidade acumulada de: 80.60917854309082
# para 320 autovetores, variabilidade acumulada de: 81.7766010761261
# para 340 autovetores, variabilidade acumulada de: 82.87188410758972
# para 360 autovetores, variabilidade acumulada de: 83.90238881111145
# para 380 autovetores, variabilidade acumulada de: 84.87507104873657
# para 400 autovetores, variabilidade acumulada de: 85.79309582710266
# para 420 autovetores, variabilidade acumulada de: 86.66240572929382
# para 440 autovetores, variabilidade acumulada de: 87.48873472213745
# para 460 autovetores, variabilidade acumulada de: 88.27510476112366
# para 480 autovetores, variabilidade acumulada de: 89.02507424354553
# para 500 autovetores, variabilidade acumulada de: 89.74002003669739
# para 520 autovetores, variabilidade acumulada de: 90.4240369796753
# para 540 autovetores, variabilidade acumulada de: 91.07813239097595
# para 560 autovetores, variabilidade acumulada de: 91.7033851146698
# para 580 autovetores, variabilidade acumulada de: 92.30262637138367
# para 600 autovetores, variabilidade acumulada de: 92.87490248680115
# para 620 autovetores, variabilidade acumulada de: 93.42305660247803
# para 640 autovetores, variabilidade acumulada de: 93.94857883453369
# para 660 autovetores, variabilidade acumulada de: 94.45195198059082
# para 680 autovetores, variabilidade acumulada de: 94.93324756622314
# para 700 autovetores, variabilidade acumulada de: 95.39455771446228
# para 720 autovetores, variabilidade acumulada de: 95.83595395088196
# para 740 autovetores, variabilidade acumulada de: 96.2580144405365
# para 760 autovetores, variabilidade acumulada de: 96.66054844856262
# para 780 autovetores, variabilidade acumulada de: 97.04440236091614
# para 800 autovetores, variabilidade acumulada de: 97.40965962409973
# para 820 autovetores, variabilidade acumulada de: 97.75660037994385
# para 840 autovetores, variabilidade acumulada de: 98.08570742607117
# para 860 autovetores, variabilidade acumulada de: 98.39673042297363
# para 880 autovetores, variabilidade acumulada de: 98.6896812915802
# para 900 autovetores, variabilidade acumulada de: 98.96472692489624
# para 920 autovetores, variabilidade acumulada de: 99.2210328578949
# para 940 autovetores, variabilidade acumulada de: 99.45712685585022
# para 960 autovetores, variabilidade acumulada de: 99.67138767242432
# para 980 autovetores, variabilidade acumulada de: 99.86317753791809
# [  0   0  20  40  60  80 100 120 140 160 180 200 220 240 260 280 300 320
#  340 360 380 400 420 440 460 480 500 520 540 560 580 600 620 640 660 680
#  700 720 740 760 780 800 820 840 860 880 900 920 940 960 980]
# [ 0.          0.         35.09192169 44.94474232 51.60194635 56.69694543
#  60.68668962 63.99464607 66.7973578  69.21147108 71.34821415 73.25896025
#  74.98707175 76.56339407 78.01278234 79.35775518 80.60917854 81.77660108
#  82.87188411 83.90238881 84.87507105 85.79309583 86.66240573 87.48873472
#  88.27510476 89.02507424 89.74002004 90.42403698 91.07813239 91.70338511
#  92.30262637 92.87490249 93.4230566  93.94857883 94.45195198 94.93324757
#  95.39455771 95.83595395 96.25801444 96.66054845 97.04440236 97.40965962
#  97.75660038 98.08570743 98.39673042 98.68968129 98.96472692 99.22103286
#  99.45712686 99.67138767 99.86317754]

# %%
plt.figure(figsize=(10,10))
plt.plot(x,y,linewidth=2.0,ms=10.0)
plt.grid()
plt.ylabel("Energia acumulada")
plt.xlabel("Autovetores")
plt.axis([0,2400,0,100])
plt.show()
